# %%
# !git clone https://github.com/francescomaldonato/RL_VPP_Thesis.git
# Out:
# Cloning into 'RL_VPP_Thesis'...
# remote: Enumerating objects: 70, done.
# remote: Counting objects: 100% (70/70), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 70 (delta 14), reused 65 (delta 12), pack-reused 0
# Unpacking objects: 100% (70/70), done.

# %%
# %cd RL_VPP_Thesis/
# %ls
# Out:
# /content/RL_VPP_Thesis
# data/                    Git_init_0.ipynb  trained_models/
# dataset_merger.ipynb     logs_model/       VPP_environment_continuos.ipynb
# ELVIS_Testing_VPP.ipynb  README.md         VPP_environment.ipynb
